# %%
print("rubain")
# Out:
# rubain

# %% [markdown]
# # A.IMPORTATION DE LIBRAIRIES

# %% [markdown]
# # .1 Tableau

# %% [markdown]
# # 1.1 Tableau a 1D

# %%
#importation de librairies

# %%
import numpy as np

# %%
#creation de tableau
tab_D1 =np.array([2,4,6,8,10,12,14,])

# %%
tab_D1
# Out:
# array([ 2,  4,  6,  8, 10, 12, 14])

# %%
# creation d'un tableau a 2D

# %%
tab_D2 = np.array([
    [14, 25, 10, 32, 14,], [19, 26, 40, 30, 14]
])

# %%
print("Rubain Ntita CHRIST:", tab_D2.shape)
print("Oradie Mbuyi MPOYI:", type(tab_D2))
print("Voici le Tableau:", tab_D2)
# Out:
# Rubain Ntita CHRIST: (2, 5)
# Oradie Mbuyi MPOYI: <class 'numpy.ndarray'>
# Voici le Tableau: [[14 25 10 32 14]
#  [19 26 40 30 14]]

# %%
#creation de tableau a 2D

# %%
tab_2D = np.array([[1,3,5,7,9],
                   [11,13,15,16,17]])

# %%
print("La dimention du tableau ----->",tab_2D.shape)
# Out:
# La dimention du tableau -----> (2, 5)

# %%
print("Le type du tableau ========>>",type(tab_2D))
# Out:
# Le type du tableau ========>> <class 'numpy.ndarray'>

# %%
print("Voici le tableau ------->  ",tab_2D)
# Out:
# Voici le tableau ------->   [[ 1  3  5  7  9]
#  [11 13 15 16 17]]

# %%
#creation de tableau a 3D
tab_3D =np.array([[[1,3,5,7,9],
                   [11,13,15,16,17],
                   [13,45,67,89,56]
                  ]])

# %%
print("La dimention du Tableau -------->",tab_3D.shape)
print("Le type du Tableau --------->",type(tab_3D))
print("Et voici le Tableau ============>> ",tab_3D)
# Out:
# La dimention du Tableau --------> (1, 3, 5)
# Le type du Tableau ---------> <class 'numpy.ndarray'>
# Et voici le Tableau ============>>  [[[ 1  3  5  7  9]
#   [11 13 15 16 17]
#   [13 45 67 89 56]]]

# %%
#creation du tableau a 4D
tab_4D = np.array([[[
    [12,54,36,87],[58,65,32,54],[78,69,19,67]
]]])

# %%
print("La dimention du Tableau -------->",tab_4D.shape)
print("Le type du Tableau --------->",type(tab_4D))
print("Et voici le Tableau ============>> ",tab_4D)
# Out:
# La dimention du Tableau --------> (1, 1, 3, 4)
# Le type du Tableau ---------> <class 'numpy.ndarray'>
# Et voici le Tableau ============>>  [[[[12 54 36 87]
#    [58 65 32 54]
#    [78 69 19 67]]]]

# %% [markdown]
# # B.OPERATIONS

# %%
a = np.array([
    [2,4,6,8],
   [25,45,65,85]
])
b = np.array([
    [20,40,50,60,],
    [214,547,658,956],
])

# %%
#Affichage du resultat
print(a.shape)
print(a)
print(b.shape)
print(b)
# Out:
# (2, 4)
# [[ 2  4  6  8]
#  [25 45 65 85]]
# (2, 4)
# [[ 20  40  50  60]
#  [214 547 658 956]]

# %%
#Resulta d'addition
print(a+b)
# Out:
# [[  22   44   56   68]
#  [ 239  592  723 1041]]

# %%
#Resultat de la soustraction
print(a-b)
# Out:
# [[ -18  -36  -44  -52]
#  [-189 -502 -593 -871]]

# %%
#Resultat de la soustraction en vice verça
print(b-a)
# Out:
# [[ 18  36  44  52]
#  [189 502 593 871]]

# %%
#Resultat de la multiplication
print(a*b)
# Out:
# [[   40   160   300   480]
#  [ 5350 24615 42770 81260]]

# %%
#Resulatat de la division
print(a/b)
# Out:
# [[0.1        0.1        0.12       0.13333333]
#  [0.11682243 0.08226691 0.09878419 0.08891213]]

# %% [markdown]
# # C.MANIPULATION

# %%
#Creation d'un dictionnaire Etudiant
Info_etudiants = {
    "Matricule": "2022020101",
    "Nom": "Rubain",
    "Prenom": "Ntita",
    "Age": 22,
    "GPA": "A"
}

# %%
#Affichage de l'information de l'etudiant
print(Info_etudiants)
# Out:
# {'Matricule': '2022020101', 'Nom': 'Rubain', 'Prenom': 'Ntita', 'Age': 22, 'GPA': 'A'}

# %%
#Dictionnaire de tout les etudiants
Infot_etudiants_bac3_gl_ia = {
    "Matricule": ["2022020101","2022021303","20220201900","2022020102","2022020301"],
    "Nom": ["Rubain","Ephraim","Oradie","Chrismie","Liliana"],
    "Prenom": ["Ntita","Tshimbela","Mbuyi","Besems","Youneill"],
    "Age": [21,20,19,19,18],
    "GPA": ["A", "B", "C", "D", "E"]
}

# %%
#L'affichage de cette celule si haut sera bien suivit apret

# %% [markdown]
# # D. VISUALISATION DE DONNEES

# %%
#Creation des données
x = np.linspace(0,2,50)

# %%
x
# Out:
# array([0.        , 0.04081633, 0.08163265, 0.12244898, 0.16326531,
#        0.20408163, 0.24489796, 0.28571429, 0.32653061, 0.36734694,
#        0.40816327, 0.44897959, 0.48979592, 0.53061224, 0.57142857,
#        0.6122449 , 0.65306122, 0.69387755, 0.73469388, 0.7755102 ,
#        0.81632653, 0.85714286, 0.89795918, 0.93877551, 0.97959184,
#        1.02040816, 1.06122449, 1.10204082, 1.14285714, 1.18367347,
#        1.2244898 , 1.26530612, 1.30612245, 1.34693878, 1.3877551 ,
#        1.42857143, 1.46938776, 1.51020408, 1.55102041, 1.59183673,
#        1.63265306, 1.67346939, 1.71428571, 1.75510204, 1.79591837,
#        1.83673469, 1.87755102, 1.91836735, 1.95918367, 2.        ])

# %%
#L'importation de matlpotlib
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots(figsize=(6,4))
ax.plot(x, x**2, label="Double")
ax.plot(x, x**2, label="Carre de x")
ax.plot(x, x**3, label="Cube de x")
ax.set_xlabel("Donnees de x")
ax.set_ylabel("Donnees de y")
plt.title("Donnees de l'espace entre 0 et 2")
ax.legend()

# %%
#L'importation du seaborn
import seaborn as sns

# %%
iris_data= sns.load_dataset('iris')
# Out:
# ---------------------------------------------------------------------------
# EmptyDataError                            Traceback (most recent call last)
# Cell In[123], line 1
# ----> 1 iris_data= sns.load_dataset('iris')
#
# File ~\anaconda3\envs\ntita_env\Lib\site-packages\seaborn\utils.py:579, in load_dataset(name, cache, data_home, **kws)
#     576 else:
#     577     full_path = url
# --> 579 df = pd.read_csv(full_path, **kws)
#     581 if df.iloc[-1].isnull().all():
#     582     df = df.iloc[:-1]
#
# ...
